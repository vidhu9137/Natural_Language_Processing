# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import os

# %% [markdown]
# # Importing Dataset

# %%
df = pd.read_csv('Text_Similarity_Dataset.csv')

# %%
df
# Out:
#                                                   text1  \
# 0     broadband challenges tv viewing the number of ...
# 1     rap boss arrested over drug find rap mogul mar...
# 2     player burn-out worries robinson england coach...
# 3     hearts of oak 3-2 cotonsport hearts of oak set...
# 4     sir paul rocks super bowl crowds sir paul mcca...
# ...                                                 ...
# 2995  uk directors guild nominees named martin scors...
# 2996  u2 to play at grammy awards show irish rock ba...
# 2997  pountney handed ban and fine northampton coach...
# 2998  belle named  best scottish band  belle & sebas...
# 2999  criminal probe on citigroup deals traders at u...
#
#                                                   text2
# 0     gardener wins double in glasgow britain s jaso...
# 1     amnesty chief laments war failure the lack of ...
# 2     hanks greeted at wintry premiere hollywood sta...
# 3     redford s vision of sundance despite sporting ...
# 4     mauresmo opens with victory in la amelie maure...
# ...                                                 ...
# 2995  steel firm  to cut  45 000 jobs mittal steel  ...
# 2996  israel looks to us for bank chief israel has a...
# 2997  india and iran in gas export deal india has si...
# 2998  mido makes third apology ahmed  mido  hossam h...
# 2999  former ni minister scott dies former northern ...
#
# [3000 rows x 2 columns]

# %% [markdown]
# # Importing librabries for text preprocessing

# %%
import re
import nltk

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
from nltk.stem.porter import PorterStemmer

# %% [markdown]
# # Text Preprocessing

# %%
#Preprocessing for the first row of dataset

# %%
X = re.sub('[^a-zA-Z]', ' ', df['text1'][0])   #only takes things made up from letters, a-z and A-Z  #No ;%&,No numbers
X = X.lower()
X = word_tokenize(X)  #split all words

# %%
Y = re.sub('[^a-zA-Z]', ' ', df['text2'][0])   
Y = Y.lower()
Y = word_tokenize(Y)

# %%
# sw contains the list of stopwords
sw = stopwords.words('english')
#ps.stem() used to stem the word to their original Eg: playing to play
ps = PorterStemmer()
l1 =[];l2 =[]

# %%
# remove stop words from the string
X_set = {ps.stem(w) for w in X if not w in sw} 
Y_set = {ps.stem(w) for w in Y if not w in sw}

# %%
X_set
# Out:
# {'abil',
#  'access',
#  'accord',
#  'adapt',
#  'ago',
#  'almost',
#  'alway',
#  'analyst',
#  'audienc',
#  'away',
#  'beauvillian',
#  'behind',
#  'big',
#  'biggest',
#  'britain',
#  'broadband',
#  'broken',
#  'brows',
#  'challeng',
#  'chang',
#  'choic',
#  'close',
#  'compani',
#  'consum',
#  'content',
#  'continu',
#  'countri',
#  'doubl',
#  'download',
#  'eat',
#  'encourag',
#  'enhanc',
#  'entertain',
#  'europ',
#  'european',
#  'expect',
#  'explod',
#  'face',
#  'fast',
#  'favour',
#  'file',
#  'film',
#  'five',
#  'found',
#  'franc',
#  'fuell',
#  'gabriel',
#  'game',
#  'germani',
#  'greatest',
#  'grow',
#  'growth',
#  'habit',
#  'high',
#  'home',
#  'hook',
#  'household',
#  'implic',
#  'inform',
#  'internet',
#  'itali',
#  'jump',
#  'jupit',
#  'keep',
#  'less',
#  'long',
#  'lower',
#  'made',
#  'major',
#  'mani',
#  'mark',
#  'market',
#  'meant',
#  'media',
#  'million',
#  'month',
#  'music',
#  'need',
#  'net',
#  'netrat',
#  'new',
#  'newspap',
#  'next',
#  'nielsen',
#  'number',
#  'olivi',
#  'one',
#  'onlin',
#  'page',
#  'particular',
#  'past',
#  'peopl',
#  'plan',
#  'play',
#  'popul',
#  'popular',
#  'predict',
#  'price',
#  'prior',
#  'quarter',
#  'radio',
#  'report',
#  'research',
#  'retain',
#  'rise',
#  'risen',
#  'rose',
#  'said',
#  'say',
#  'see',
#  'seismic',
#  'shift',
#  'show',
#  'spain',
#  'spare',
#  'speed',
#  'spend',
#  'spent',
#  'studi',
#  'subscript',
#  'suggest',
#  'surfer',
#  'televis',
#  'term',
#  'third',
#  'threat',
#  'time',
#  'total',
#  'turn',
#  'tv',
#  'twelv',
#  'uk',
#  'updat',
#  'user',
#  'via',
#  'view',
#  'visitor',
#  'watch',
#  'web',
#  'websit',
#  'wider',
#  'year'}

# %%
Y_set
# Out:
# {'abraham',
#  'add',
#  'adrift',
#  'ahead',
#  'alexi',
#  'also',
#  'american',
#  'anoth',
#  'appear',
#  'athen',
#  'back',
#  'beat',
#  'behind',
#  'believ',
#  'best',
#  'botch',
#  'break',
#  'brett',
#  'britain',
#  'british',
#  'buckfield',
#  'came',
#  'catherin',
#  'champion',
#  'chanc',
#  'changeov',
#  'chri',
#  'claim',
#  'claxton',
#  'clear',
#  'clearanc',
#  'close',
#  'closer',
#  'cm',
#  'come',
#  'competit',
#  'cost',
#  'coupl',
#  'cruis',
#  'daniel',
#  'djhone',
#  'doubl',
#  'edg',
#  'end',
#  'enjoy',
#  'event',
#  'excit',
#  'expect',
#  'fade',
#  'feat',
#  'fedorova',
#  'final',
#  'finish',
#  'first',
#  'fit',
#  'fourth',
#  'franc',
#  'garden',
#  'get',
#  'glasgow',
#  'gold',
#  'got',
#  'grab',
#  'green',
#  'hard',
#  'held',
#  'high',
#  'hold',
#  'holm',
#  'home',
#  'hope',
#  'hurdl',
#  'import',
#  'indoor',
#  'injuri',
#  'intern',
#  'invit',
#  'irina',
#  'itali',
#  'jade',
#  'jame',
#  'jason',
#  'jenni',
#  'johnson',
#  'jump',
#  'kallur',
#  'kick',
#  'lambert',
#  'last',
#  'leap',
#  'led',
#  'lesli',
#  'long',
#  'lot',
#  'luca',
#  'maduaka',
#  'major',
#  'make',
#  'mark',
#  'mauric',
#  'maximum',
#  'meadow',
#  'meet',
#  'men',
#  'metr',
#  'miss',
#  'month',
#  'murphi',
#  'need',
#  'new',
#  'next',
#  'nick',
#  'norwich',
#  'oke',
#  'old',
#  'olga',
#  'olymp',
#  'one',
#  'outing',
#  'person',
#  'persson',
#  'place',
#  'podium',
#  'point',
#  'pole',
#  'poor',
#  'produc',
#  'quartet',
#  'race',
#  'record',
#  'recov',
#  'recurr',
#  'relay',
#  'repeat',
#  'rund',
#  'russia',
#  'russian',
#  'said',
#  'sarah',
#  'scot',
#  'season',
#  'sec',
#  'second',
#  'set',
#  'setback',
#  'settl',
#  'sharpen',
#  'shevchenko',
#  'shock',
#  'short',
#  'sinc',
#  'smith',
#  'soil',
#  'stage',
#  'start',
#  'stefan',
#  'success',
#  'suffer',
#  'sure',
#  'swede',
#  'sweden',
#  'thie',
#  'third',
#  'time',
#  'took',
#  'tosin',
#  'total',
#  'train',
#  'tripl',
#  'unabl',
#  'unbeaten',
#  'union',
#  'vault',
#  'verdecchia',
#  'victori',
#  'way',
#  'well',
#  'win',
#  'women',
#  'world',
#  'x',
#  'year',
#  'yet'}

# %%
# form a set containing keywords of both strings 
rvector = X_set.union(Y_set) 
for w in rvector:
    if w in X_set: l1.append(1) # create a vector
    else: l1.append(0)
    if w in Y_set: l2.append(1)
    else: l2.append(0)

# %%
len(l1)
# Out:
# 302

# %%
len(l2)
# Out:
# 302

# %%
c = 0
  
# cosine formula for finding similarity score b/w l1 and l2
for i in range(len(rvector)):
    c+= l1[i]*l2[i]
cosine = c / float((sum(l1)*sum(l2))**0.5)
print("similarity: ", cosine)
# Out:
# similarity:  0.14267836335553657

# %%
#Applying the above operations on the whole dataframe

# %%
def count_frequency(word_list):   #function for creating dictionary of frequencies for all words
      
    D = {}
      
    for new_word in word_list:
          
        if new_word in D:
            D[new_word] = D[new_word] + 1
              
        else:
            D[new_word] = 1
              
    return D

# %%
import math    

#All functions used for finding cosine value i.e. used for similarity score

def dotproduct(v1, v2):
    return sum((a*b) for a, b in zip(v1, v2))

def length(v):
    return math.sqrt(dotproduct(v, v))

def angle(v1, v2):
    return math.acos(dotproduct(v1, v2) / (length(v1) * length(v2)))

def cosine_angle(v1, v2):
    return dotproduct(v1, v2) / (length(v1) * length(v2))

# %%
#Creating a for loop for preprocessing and similarity score calculation of whole dataframe

# %%
sw = stopwords.words('english') 
ps = PorterStemmer()

for i in range(0, 3000):
    X = re.sub('[^a-zA-Z]', ' ', df['text1'][i])  
    X = X.lower()
    X = word_tokenize(X) 
    
    Y = re.sub('[^a-zA-Z]', ' ', df['text2'][i]) 
    Y = Y.lower()
    Y = word_tokenize(Y)  
    
    l1 =[];l2 =[]
    
    X_set = {ps.stem(w) for w in X if not w in sw} 
    Y_set = {ps.stem(w) for w in Y if not w in sw}
    
    D1 = count_frequency(X_set)
    D2 = count_frequency(Y_set)
    
    rvector = X_set.union(Y_set) 
    for w in rvector:
        if w in X_set: l1.append(1) # create a vector
        else: l1.append(0)
        if w in Y_set: l2.append(1)
        else: l2.append(0)
    
    print('Row index: ', i)
    print('Similarity: ', cosine_angle(l1, l2))
# Out:
# Row index:  0
# Similarity:  0.14267836335553657
# Row index:  1
# Similarity:  0.0674199862463242
# Row index:  2
# Similarity:  0.07297211359952455
# Row index:  3
# Similarity:  0.07644974551833317
# Row index:  4
# Similarity:  0.134637813499663
# Row index:  5
# Similarity:  0.11155885718343433
# Row index:  6
# Similarity:  0.03820455033741685
# Row index:  7
# Similarity:  0.09363006756991821
# Row index:  8
# Similarity:  0.04195315943520017
# Row index:  9
# Similarity:  0.0849250307237733
# Row index:  10
# Similarity:  0.13705061117171075
# Row index:  11
# Similarity:  0.09415130835240083
# Row index:  12
# Similarity:  0.15302805979888587
# Row index:  13
# Similarity:  0.1563215837502731
# Row index:  14
# Similarity:  0.08422919413386756
# Row index:  15
# Similarity:  0.06834861261734088
# Row index:  16
# Similarity:  0.2393851149226017
# Row index:  17
# Similarity:  0.2839536610926862
# Row index:  18
# Similarity:  0.10333567582603505
# Row index:  19
# Similarity:  0.0894141111609582
# Row index:  20
# Similarity:  0.10836965077746659
# Row index:  21
# Similarity:  0.13077696928039353
# Row index:  22
# Similarity:  0.1059254282664752
# Row index:  23
# Similarity:  0.03472910828409683
# Row index:  24
# Similarity:  0.14520900769964853
# Row index:  25
# Similarity:  0.07443802074084642
# Row index:  26
# Similarity:  0.06656735199784074
# Row index:  27
# Similarity:  0.09495590766897964
# Row index:  28
# Similarity:  0.08547008547008546
# Row index:  29
# Similarity:  0.08491487340229038
# Row index:  30
# Similarity:  0.052083333333333336
# Row index:  31
# Similarity:  0.14439129429249156
# Row index:  32
# Similarity:  0.12909944487358055
# Row index:  33
# Similarity:  0.03946685189819292
# Row index:  34
# Similarity:  0.10350622395370347
# Row index:  35
# Similarity:  0.13381128194421082
# Row index:  36
# Similarity:  0.14000784271590008
# Row index:  37
# Similarity:  0.15397403831649878
# Row index:  38
# Similarity:  0.0846625368556791
# Row index:  39
# Similarity:  0.08304150286550151
# Row index:  40
# Similarity:  0.10638078975070424
# Row index:  41
# Similarity:  0.12327321425382481
# Row index:  42
# Similarity:  0.1347761731171854
# Row index:  43
# Similarity:  0.06766029953064391
# Row index:  44
# Similarity:  0.1150870675296872
# Row index:  45
# Similarity:  0.1308699387015766
# Row index:  46
# Similarity:  0.14424222532750067
# Row index:  47
# Similarity:  0.07293249574894728
# Row index:  48
# Similarity:  0.09225312080288849
# Row index:  49
# Similarity:  0.07764369457390996
# Row index:  50
# Similarity:  0.10478243557698858
# Row index:  51
# Similarity:  0.10169503597462533
# Row index:  52
# Similarity:  0.040412287809801765
# Row index:  53
# Similarity:  0.13199571020912618
# Row index:  54
# Similarity:  0.1310972338775475
# Row index:  55
# Similarity:  0.15336167709578988
# Row index:  56
# Similarity:  0.10360237735649558
# Row index:  57
# Similarity:  0.10189239324240282
# Row index:  58
# Similarity:  0.06749139275988526
# Row index:  59
# Similarity:  0.05414007696006361
# Row index:  60
# Similarity:  0.09384168706347816
# Row index:  61
# Similarity:  0.07854469636559851
# Row index:  62
# Similarity:  0.061920237450665445
# Row index:  63
# Similarity:  0.04926646390821466
# Row index:  64
# Similarity:  0.13498278551977053
# Row index:  65
# Similarity:  0.08181209126014324
# Row index:  66
# Similarity:  0.07316393139022627
# Row index:  67
# Similarity:  0.10660035817780524
# Row index:  68
# Similarity:  0.07540461810874112
# Row index:  69
# Similarity:  0.023544080467400554
# Row index:  70
# Similarity:  0.06370220572706062
# Row index:  71
# Similarity:  0.10783277320343841
# Row index:  72
# Similarity:  0.10778636357219329
# Row index:  73
# Similarity:  0.09440686400617013
# Row index:  74
# Similarity:  0.14131671592979872
# Row index:  75
# Similarity:  0.0574959574576069
# Row index:  76
# Similarity:  0.1308489790701575
# Row index:  77
# Similarity:  0.0794536482818189
# Row index:  78
# Similarity:  0.09450859557017612
# Row index:  79
# Similarity:  0.10766959615176361
# Row index:  80
# Similarity:  0.0920216595649358
# Row index:  81
# Similarity:  0.055618651039326214
# Row index:  82
# Similarity:  0.07720843337537842
# Row index:  83
# Similarity:  0.1903297204970161
# Row index:  84
# Similarity:  0.10835053021731819
# Row index:  85
# Similarity:  0.08661986608440463
# Row index:  86
# Similarity:  0.1394169854285507
# Row index:  87
# Similarity:  0.07099169533382993
# Row index:  88
# Similarity:  0.09061929248807808
# Row index:  89
# Similarity:  0.014341432155294377
# Row index:  90
# Similarity:  0.0814173684098662
# Row index:  91
# Similarity:  0.08263008587939974
# Row index:  92
# Similarity:  0.0924335751993652
# Row index:  93
# Similarity:  0.14955158151851694
# Row index:  94
# Similarity:  0.08081220356417686
# Row index:  95
# Similarity:  0.04273521617236423
# Row index:  96
# Similarity:  0.08598154393102571
# Row index:  97
# Similarity:  0.05010973520018859
# Row index:  98
# Similarity:  0.1631543544914745
# Row index:  99
# Similarity:  0.08733707726295863
# Row index:  100
# Similarity:  0.07973527026935094
# Row index:  101
# Similarity:  0.112962014264383
# Row index:  102
# Similarity:  0.08475223015516377
# Row index:  103
# Similarity:  0.10746029273566866
# Row index:  104
# Similarity:  0.04964275442411214
# Row index:  105
# Similarity:  0.09902233901975123
# Row index:  106
# Similarity:  0.17451891814894502
# Row index:  107
# Similarity:  0.0962180848964019
# Row index:  108
# Similarity:  0.09600699910855089
# Row index:  109
# Similarity:  0.06256112470898544
# Row index:  110
# Similarity:  0.07968190728895957
# Row index:  111
# Similarity:  0.06833624338032501
# Row index:  112
# Similarity:  0.1544542579198825
# Row index:  113
# Similarity:  0.046733309148852105
# Row index:  114
# Similarity:  0.22754898976351917
# Row index:  115
# Similarity:  0.13078709094514926
# Row index:  116
# Similarity:  0.07749130248475834
# Row index:  117
# Similarity:  0.08721373662544792
# Row index:  118
# Similarity:  0.08913482586582298
# Row index:  119
# Similarity:  0.07774288420142415
# Row index:  120
# Similarity:  0.06904309634237427
# Row index:  121
# Similarity:  0.19732422371543296
# Row index:  122
# Similarity:  0.12252431251824965
# Row index:  123
# Similarity:  0.03825343653826906
# Row index:  124
# Similarity:  0.09332565252573828
# Row index:  125
# Similarity:  0.11454053224818188
# Row index:  126
# Similarity:  0.11227217828476797
# Row index:  127
# Similarity:  0.1651601361555603
# Row index:  128
# Similarity:  0.10557434432865279
# Row index:  129
# Similarity:  0.08541706335273443
# Row index:  130
# Similarity:  0.032501354251307964
# Row index:  131
# Similarity:  0.08163333305850111
# Row index:  132
# Similarity:  0.12248780175431365
# Row index:  133
# Similarity:  0.0875428396003061
# Row index:  134
# Similarity:  0.08092611808313843
# Row index:  135
# Similarity:  0.16931081039656662
# Row index:  136
# Similarity:  0.07261785883857189
# Row index:  137
# Similarity:  0.05626711509056694
# Row index:  138
# Similarity:  0.13957263155977062
# Row index:  139
# Similarity:  0.2523362194486609
# Row index:  140
# Similarity:  0.15762208124782012
# Row index:  141
# Similarity:  0.06274558051381586
# Row index:  142
# Similarity:  0.0770668563678234
# Row index:  143
# Similarity:  0.1309681589627518
# Row index:  144
# Similarity:  0.12943416009667144
# Row index:  145
# Similarity:  0.027704244399894037
# Row index:  146
# Similarity:  0.12300118078293078
# Row index:  147
# Similarity:  0.09622504486493763
# Row index:  148
# Similarity:  0.11850952152281062
# Row index:  149
# Similarity:  0.08730536198471833
# Row index:  150
# Similarity:  0.18780338843828168
# Row index:  151
# Similarity:  0.08891801772736012
# Row index:  152
# Similarity:  0.2396944224404655
# Row index:  153
# Similarity:  0.12711879496828168
# Row index:  154
# Similarity:  0.05524946201098299
# Row index:  155
# Similarity:  0.07463517925331652
# Row index:  156
# Similarity:  0.06609789738588476
# Row index:  157
# Similarity:  0.09479940983242018
# Row index:  158
# Similarity:  0.08972792878662851
# Row index:  159
# Similarity:  0.09901475429766743
# Row index:  160
# Similarity:  0.11313725608601642
# Row index:  161
# Similarity:  0.16226041422818285
# Row index:  162
# Similarity:  0.12763208779032997
# Row index:  163
# Similarity:  0.09127359190541251
# Row index:  164
# Similarity:  0.12413175043086072
# Row index:  165
# Similarity:  0.10018048746260763
# Row index:  166
# Similarity:  0.13333699146284095
# Row index:  167
# Similarity:  0.06139245572364643
# Row index:  168
# Similarity:  0.10161212741561738
# Row index:  169
# Similarity:  0.1107556001495066
# Row index:  170
# Similarity:  0.09181023240329131
# Row index:  171
# Similarity:  0.040754249463367
# Row index:  172
# Similarity:  0.04638916172844008
# Row index:  173
# Similarity:  0.1407528472839086
# Row index:  174
# Similarity:  0.08102265201095855
# Row index:  175
# Similarity:  0.10281097829222208
# Row index:  176
# Similarity:  0.0484001932913979
# Row index:  177
# Similarity:  0.15353417865326588
# Row index:  178
# Similarity:  0.12396776437619818
# Row index:  179
# Similarity:  0.14034975072346967
# Row index:  180
# Similarity:  0.18032337172796767
# Row index:  181
# Similarity:  0.04341902305016682
# Row index:  182
# Similarity:  0.10713739108887085
# Row index:  183
# Similarity:  0.059502262781851445
# Row index:  184
# Similarity:  0.10699012312772821
# Row index:  185
# Similarity:  0.12622409075592608
# Row index:  186
# Similarity:  0.08886586164189825
# Row index:  187
# Similarity:  0.13668700327812827
# Row index:  188
# Similarity:  0.06006249751303726
# Row index:  189
# Similarity:  0.09309040850691779
# Row index:  190
# Similarity:  0.05910541245655416
# Row index:  191
# Similarity:  0.06595575120547419
# Row index:  192
# Similarity:  0.09587062360592129
# Row index:  193
# Similarity:  0.07576144084141581
# Row index:  194
# Similarity:  0.048785712015685295
# Row index:  195
# Similarity:  0.14305114154288537
# Row index:  196
# Similarity:  0.11252332517309617
# Row index:  197
# Similarity:  0.06711933820990239
# Row index:  198
# Similarity:  0.10681625531636751
# Row index:  199
# Similarity:  0.13451854182690987
# Row index:  200
# Similarity:  0.11704114719613058
# Row index:  201
# Similarity:  0.054737235123054825
# Row index:  202
# Similarity:  0.06378124596837308
# Row index:  203
# Similarity:  0.08698189998335926
# Row index:  204
# Similarity:  0.07495316889958614
# Row index:  205
# Similarity:  0.0936383021536753
# Row index:  206
# Similarity:  0.07444375004781978
# Row index:  207
# Similarity:  0.12666856670941773
# Row index:  208
# Similarity:  0.0759435314054806
# Row index:  209
# Similarity:  0.03796631983009996
# Row index:  210
# Similarity:  0.11873237267750118
# Row index:  211
# Similarity:  0.033072537342610564
# Row index:  212
# Similarity:  0.09315332801332622
# Row index:  213
# Similarity:  0.14721987144357493
# Row index:  214
# Similarity:  0.13478934738386475
# Row index:  215
# Similarity:  0.05846054221936677
# Row index:  216
# Similarity:  0.026444294267397254
# Row index:  217
# Similarity:  0.08771413225336316
# Row index:  218
# Similarity:  0.06431196942844081
# Row index:  219
# Similarity:  0.08997287164572494
# Row index:  220
# Similarity:  0.12341277798805193
# Row index:  221
# Similarity:  0.1432979802986566
# Row index:  222
# Similarity:  0.027183014110978114
# Row index:  223
# Similarity:  0.08064429233139023
# Row index:  224
# Similarity:  0.12113592796308724
# Row index:  225
# Similarity:  0.14811868988405846
# Row index:  226
# Similarity:  0.33885031047455877
# Row index:  227
# Similarity:  0.19063276772455937
# Row index:  228
# Similarity:  0.14920941939059815
# Row index:  229
# Similarity:  0.07885355310059193
# Row index:  230
# Similarity:  0.08287560426959469
# Row index:  231
# Similarity:  0.06872329711433423
# Row index:  232
# Similarity:  0.07970423653341889
# Row index:  233
# Similarity:  0.03030457633656632
# Row index:  234
# Similarity:  0.06790677947220895
# Row index:  235
# Similarity:  0.06596992457003135
# Row index:  236
# Similarity:  0.12006116784431532
# Row index:  237
# Similarity:  0.041158188450019624
# Row index:  238
# Similarity:  0.0820412654142367
# Row index:  239
# Similarity:  0.0924863374504321
# Row index:  240
# Similarity:  0.0651087763376237
# Row index:  241
# Similarity:  0.10988384396648085
# Row index:  242
# Similarity:  0.10040241611281235
# Row index:  243
# Similarity:  0.062173662148902784
# Row index:  244
# Similarity:  0.10890201615584084
# Row index:  245
# Similarity:  0.047710417797634214
# Row index:  246
# Similarity:  0.12714567779519373
# Row index:  247
# Similarity:  0.09104912108299729
# Row index:  248
# Similarity:  0.07945756717739365
# Row index:  249
# Similarity:  0.09796244778275266
# Row index:  250
# Similarity:  0.03569863684011106
# Row index:  251
# Similarity:  0.3147776880673489
# Row index:  252
# Similarity:  0.09912414275411366
# Row index:  253
# Similarity:  0.08645856265563524
# Row index:  254
# Similarity:  0.105777177069589
# Row index:  255
# Similarity:  0.08950019446976963
# Row index:  256
# Similarity:  0.07328951347325134
# Row index:  257
# Similarity:  0.09013518919715106
# Row index:  258
# Similarity:  0.07363703306697986
# Row index:  259
# Similarity:  0.11604163148067773
# Row index:  260
# Similarity:  0.09660145050098941
# Row index:  261
# Similarity:  0.07166465955784342
# Row index:  262
# Similarity:  0.07755667343294811
# Row index:  263
# Similarity:  0.18228276635825297
# Row index:  264
# Similarity:  0.09653391119992655
# Row index:  265
# Similarity:  0.10789791190813058
# Row index:  266
# Similarity:  0.17197801086768577
# Row index:  267
# Similarity:  0.115725377651796
# Row index:  268
# Similarity:  0.14811970539375383
# Row index:  269
# Similarity:  0.05481612620668933
# Row index:  270
# Similarity:  0.08977584024968696
# Row index:  271
# Similarity:  0.13787472597278894
# Row index:  272
# Similarity:  0.10218988991416096
# Row index:  273
# Similarity:  0.13309299706142555
# Row index:  274
# Similarity:  0.1412876560360782
# Row index:  275
# Similarity:  0.10369516947304254
# Row index:  276
# Similarity:  0.10186448740876905
# Row index:  277
# Similarity:  0.16363561492640652
# Row index:  278
# Similarity:  0.06566661641294395
# Row index:  279
# Similarity:  0.05896254202170251
# Row index:  280
# Similarity:  0.09251867765971723
# Row index:  281
# Similarity:  0.09017205462529541
# Row index:  282
# Similarity:  0.03140371465106638
# Row index:  283
# Similarity:  0.07730429961089472
# Row index:  284
# Similarity:  0.032929277996907105
# Row index:  285
# Similarity:  0.026897176986827715
# Row index:  286
# Similarity:  0.0916544468883458
# Row index:  287
# Similarity:  0.07673882976766815
# Row index:  288
# Similarity:  0.05735393346764045
# Row index:  289
# Similarity:  0.10231774231571236
# Row index:  290
# Similarity:  0.09048748253832699
# Row index:  291
# Similarity:  0.07856742013183862
# Row index:  292
# Similarity:  0.15430794252872423
# Row index:  293
# Similarity:  0.05950178508032901
# Row index:  294
# Similarity:  0.06723686236013819
# Row index:  295
# Similarity:  0.20062015652712703
# Row index:  296
# Similarity:  0.12156613477096617
# Row index:  297
# Similarity:  0.1279619826583191
# Row index:  298
# Similarity:  0.08124444637023875
# Row index:  299
# Similarity:  0.056493268286603206
# Row index:  300
# Similarity:  0.06662503902185435
# Row index:  301
# Similarity:  0.1466471150213533
# Row index:  302
# Similarity:  0.12467040683497509
# Row index:  303
# Similarity:  0.07967684860201743
# Row index:  304
# Similarity:  0.08658450381876093
# Row index:  305
# Similarity:  0.06662966046527696
# Row index:  306
# Similarity:  0.15000154961078946
# Row index:  307
# Similarity:  0.13242427890476505
# Row index:  308
# Similarity:  0.1827875625337779
# Row index:  309
# Similarity:  0.16971105832553265
# Row index:  310
# Similarity:  0.1081278556848749
# Row index:  311
# Similarity:  0.11952286093343938
# Row index:  312
# Similarity:  0.1367683233103697
# Row index:  313
# Similarity:  0.11336125294397117
# Row index:  314
# Similarity:  0.07100469468046931
# Row index:  315
# Similarity:  0.20473090046483966
# Row index:  316
# Similarity:  0.10024783185467542
# Row index:  317
# Similarity:  0.08520595739981648
# Row index:  318
# Similarity:  0.07216878364870322
# Row index:  319
# Similarity:  0.06880377396207346
# Row index:  320
# Similarity:  0.06428658552244854
# Row index:  321
# Similarity:  0.0660323183475926
# Row index:  322
# Similarity:  0.10898088293170863
# Row index:  323
# Similarity:  0.13271218656114264
# Row index:  324
# Similarity:  0.09888020503820574
# Row index:  325
# Similarity:  0.10901013862728075
# Row index:  326
# Similarity:  0.09690941652527747
# Row index:  327
# Similarity:  0.09431164778022316
# Row index:  328
# Similarity:  0.08728715609439695
# Row index:  329
# Similarity:  0.07686483672655527
# Row index:  330
# Similarity:  0.08988968316207743
# Row index:  331
# Similarity:  0.08959403681935736
# Row index:  332
# Similarity:  0.09164023579485961
# Row index:  333
# Similarity:  0.06748575116481824
# Row index:  334
# Similarity:  0.05765820050180531
# Row index:  335
# Similarity:  0.026410456384992915
# Row index:  336
# Similarity:  0.07374552037788236
# Row index:  337
# Similarity:  0.12855158986961052
# Row index:  338
# Similarity:  0.06576848315559868
# Row index:  339
# Similarity:  0.10415913227971481
# Row index:  340
# Similarity:  0.05830404870173485
# Row index:  341
# Similarity:  0.10403129732205989
# Row index:  342
# Similarity:  0.09160372067518134
# Row index:  343
# Similarity:  0.11616772098016666
# Row index:  344
# Similarity:  0.06357958771848289
# Row index:  345
# Similarity:  0.09325048082403138
# Row index:  346
# Similarity:  0.07542017135482397
# Row index:  347
# Similarity:  0.1556997888323046
# Row index:  348
# Similarity:  0.06558978056975615
# Row index:  349
# Similarity:  0.09311293720016549
# Row index:  350
# Similarity:  0.08492077756084468
# Row index:  351
# Similarity:  0.14896132831643122
# Row index:  352
# Similarity:  0.16468926425678324
# Row index:  353
# Similarity:  0.05596956083610695
# Row index:  354
# Similarity:  0.049456265418047485
# Row index:  355
# Similarity:  0.13300353809202717
# Row index:  356
# Similarity:  0.12869517157249538
# Row index:  357
# Similarity:  0.05547872968297112
# Row index:  358
# Similarity:  0.043314808182421
# Row index:  359
# Similarity:  0.07830153977496952
# Row index:  360
# Similarity:  0.06916531824073616
# Row index:  361
# Similarity:  0.154258383226484
# Row index:  362
# Similarity:  0.03630966210657986
# Row index:  363
# Similarity:  0.13991814053061055
# Row index:  364
# Similarity:  0.15900879764848913
# Row index:  365
# Similarity:  0.1988536812099246
# Row index:  366
# Similarity:  0.0653520993415403
# Row index:  367
# Similarity:  0.047189998458066824
# Row index:  368
# Similarity:  0.10102135422603399
# Row index:  369
# Similarity:  0.07789945341703662
# Row index:  370
# Similarity:  0.16544152150649305
# Row index:  371
# Similarity:  0.040839957758799755
# Row index:  372
# Similarity:  0.20017925304542367
# Row index:  373
# Similarity:  0.1421193025333046
# Row index:  374
# Similarity:  0.13300397918683549
# Row index:  375
# Similarity:  0.08419545455622986
# Row index:  376
# Similarity:  0.10421296838478876
# Row index:  377
# Similarity:  0.15747104765829611
# Row index:  378
# Similarity:  0.06110161274177645
# Row index:  379
# Similarity:  0.10119453729458627
# Row index:  380
# Similarity:  0.09529323477053278
# Row index:  381
# Similarity:  0.09210725649786139
# Row index:  382
# Similarity:  0.08726868848473414
# Row index:  383
# Similarity:  0.03644471480623968
# Row index:  384
# Similarity:  0.16806091162617773
# Row index:  385
# Similarity:  0.03344350678423543
# Row index:  386
# Similarity:  0.08589195027644385
# Row index:  387
# Similarity:  0.12305872047043782
# Row index:  388
# Similarity:  0.09459381485717672
# Row index:  389
# Similarity:  0.06317539727139919
# Row index:  390
# Similarity:  0.048850865146712434
# Row index:  391
# Similarity:  0.04419417382415922
# Row index:  392
# Similarity:  0.06898644619872629
# Row index:  393
# Similarity:  0.13730476750355963
# Row index:  394
# Similarity:  0.09087085364518736
# Row index:  395
# Similarity:  0.06414796757275354
# Row index:  396
# Similarity:  0.11087107424795299
# Row index:  397
# Similarity:  0.09694584179118518
# Row index:  398
# Similarity:  0.10359692675134351
# Row index:  399
# Similarity:  0.1070240099345042
# Row index:  400
# Similarity:  0.08339054812437388
# Row index:  401
# Similarity:  0.05219673066620771
# Row index:  402
# Similarity:  0.0942421293656315
# Row index:  403
# Similarity:  0.12081741982925447
# Row index:  404
# Similarity:  0.10658960801980241
# Row index:  405
# Similarity:  0.11245163050283553
# Row index:  406
# Similarity:  0.039069919580296736
# Row index:  407
# Similarity:  0.12789136689584626
# Row index:  408
# Similarity:  0.04414301223487347
# Row index:  409
# Similarity:  0.17118187465036325
# Row index:  410
# Similarity:  0.02753336618303821
# Row index:  411
# Similarity:  0.10012523486435179
# Row index:  412
# Similarity:  0.14302610464636437
# Row index:  413
# Similarity:  0.07567076746075031
# Row index:  414
# Similarity:  0.10212858423763307
# Row index:  415
# Similarity:  0.08084520834544433
# Row index:  416
# Similarity:  0.04210759605332595
# Row index:  417
# Similarity:  0.1326716253613319
# Row index:  418
# Similarity:  0.18709804827093438
# Row index:  419
# Similarity:  0.06798730455620051
# Row index:  420
# Similarity:  0.07828684767618646
# Row index:  421
# Similarity:  0.09123009191732889
# Row index:  422
# Similarity:  0.13150757255883821
# Row index:  423
# Similarity:  0.13004654198899326
# Row index:  424
# Similarity:  0.22445701677816263
# Row index:  425
# Similarity:  0.13130643285972254
# Row index:  426
# Similarity:  0.029939247542604786
# Row index:  427
# Similarity:  0.08944271909999157
# Row index:  428
# Similarity:  0.07190916418846247
# Row index:  429
# Similarity:  0.05838742081211422
# Row index:  430
# Similarity:  0.1348242847612911
# Row index:  431
# Similarity:  0.05918461518335705
# Row index:  432
# Similarity:  0.08966616664080815
# Row index:  433
# Similarity:  0.15987532483831998
# Row index:  434
# Similarity:  0.0668762678035098
# Row index:  435
# Similarity:  0.14682606967715953
# Row index:  436
# Similarity:  0.06886834304297229
# Row index:  437
# Similarity:  0.060599383355932256
# Row index:  438
# Similarity:  0.15974461276617433
# Row index:  439
# Similarity:  0.07979188926993101
# Row index:  440
# Similarity:  0.08809763918432062
# Row index:  441
# Similarity:  0.06716604942594677
# Row index:  442
# Similarity:  0.07020545658013636
# Row index:  443
# Similarity:  0.07432432432432434
# Row index:  444
# Similarity:  0.09681686578154076
# Row index:  445
# Similarity:  0.1420402710377984
# Row index:  446
# Similarity:  0.11933166594877916
# Row index:  447
# Similarity:  0.04915473998202097
# Row index:  448
# Similarity:  0.09982743731749959
# Row index:  449
# Similarity:  0.1103217531589738
# Row index:  450
# Similarity:  0.1338814053258282
# Row index:  451
# Similarity:  0.07603756252309957
# Row index:  452
# Similarity:  0.03798357034142275
# Row index:  453
# Similarity:  0.054652152981996084
# Row index:  454
# Similarity:  0.08292047852302423
# Row index:  455
# Similarity:  0.12295495018192258
# Row index:  456
# Similarity:  0.08563532077378401
# Row index:  457
# Similarity:  0.0662266178532522
# Row index:  458
# Similarity:  0.12503618468739855
# Row index:  459
# Similarity:  0.0690796948587756
# Row index:  460
# Similarity:  0.0991709196122835
# Row index:  461
# Similarity:  0.03340765523905305
# Row index:  462
# Similarity:  0.11163344957649059
# Row index:  463
# Similarity:  0.10731248487807117
# Row index:  464
# Similarity:  0.14754222271266348
# Row index:  465
# Similarity:  0.09106159954822177
# Row index:  466
# Similarity:  0.13699915608779775
# Row index:  467
# Similarity:  0.10237497442500501
# Row index:  468
# Similarity:  0.06003002251876642
# Row index:  469
# Similarity:  0.05671782581081438
# Row index:  470
# Similarity:  0.08160942667466478
# Row index:  471
# Similarity:  0.05799937131886384
# Row index:  472
# Similarity:  0.1670653091045332
# Row index:  473
# Similarity:  0.08468097984399411
# Row index:  474
# Similarity:  0.04398505465810612
# Row index:  475
# Similarity:  0.07838858845552175
# Row index:  476
# Similarity:  0.0782024520518881
# Row index:  477
# Similarity:  0.10855649121315493
# Row index:  478
# Similarity:  0.0641688947919748
# Row index:  479
# Similarity:  0.09036872237173582
# Row index:  480
# Similarity:  0.09886896315592926
# Row index:  481
# Similarity:  0.07264626627224846
# Row index:  482
# Similarity:  0.04750845494789375
# Row index:  483
# Similarity:  0.06314696303710866
# Row index:  484
# Similarity:  0.1286499552652021
# Row index:  485
# Similarity:  0.056374945100519644
# Row index:  486
# Similarity:  0.11445990820414162
# Row index:  487
# Similarity:  0.10844353369380766
# Row index:  488
# Similarity:  0.10705186531570644
# Row index:  489
# Similarity:  0.158999682000954
# Row index:  490
# Similarity:  0.12411384919401103
# Row index:  491
# Similarity:  0.14776869345665739
# Row index:  492
# Similarity:  0.10256545123110546
# Row index:  493
# Similarity:  0.08391813582966891
# Row index:  494
# Similarity:  0.10997402450983054
# Row index:  495
# Similarity:  0.058236353493475654
# Row index:  496
# Similarity:  0.12439616414631
# Row index:  497
# Similarity:  0.1699462507084179
# Row index:  498
# Similarity:  0.19222018291040574
# Row index:  499
# Similarity:  0.109509474074421
# Row index:  500
# Similarity:  0.03991228933928331
# Row index:  501
# Similarity:  0.07624928516630233
# Row index:  502
# Similarity:  0.18049718195559616
# Row index:  503
# Similarity:  0.12102703617330599
# Row index:  504
# Similarity:  0.09233103583065962
# Row index:  505
# Similarity:  0.07631504566594771
# Row index:  506
# Similarity:  0.1058693826616842
# Row index:  507
# Similarity:  0.12070196981508372
# Row index:  508
# Similarity:  0.07408121303555024
# Row index:  509
# Similarity:  0.02344036154692477
# Row index:  510
# Similarity:  0.10550087574332591
# Row index:  511
# Similarity:  0.11401543113259059
# Row index:  512
# Similarity:  0.08971041894602579
# Row index:  513
# Similarity:  0.07240486142559964
# Row index:  514
# Similarity:  0.11456971959327358
# Row index:  515
# Similarity:  0.05997601439040672
# Row index:  516
# Similarity:  0.07728550279191397
# Row index:  517
# Similarity:  0.10828114425674669
# Row index:  518
# Similarity:  0.052372293656638175
# Row index:  519
# Similarity:  0.04218714595286695
# Row index:  520
# Similarity:  0.14821593499596356
# Row index:  521
# Similarity:  0.13381594098395005
# Row index:  522
# Similarity:  0.1168578667620716
# Row index:  523
# Similarity:  0.05705236958467228
# Row index:  524
# Similarity:  0.07336008596285569
# Row index:  525
# Similarity:  0.09602684682780276
# Row index:  526
# Similarity:  0.07831121810237904
# Row index:  527
# Similarity:  0.06949110375816135
# Row index:  528
# Similarity:  0.11398071795439749
# Row index:  529
# Similarity:  0.07175929248875693
# Row index:  530
# Similarity:  0.12475456643256737
# Row index:  531
# Similarity:  0.06594512717503578
# Row index:  532
# Similarity:  0.057091904964073396
# Row index:  533
# Similarity:  0.10189163764157934
# Row index:  534
# Similarity:  0.037725777658606706
# Row index:  535
# Similarity:  0.07078061945931272
# Row index:  536
# Similarity:  0.049374193110101876
# Row index:  537
# Similarity:  0.090267093384844
# Row index:  538
# Similarity:  0.0609225644135158
# Row index:  539
# Similarity:  0.08008741579734115
# Row index:  540
# Similarity:  0.12055655821617572
# Row index:  541
# Similarity:  0.10948196824072451
# Row index:  542
# Similarity:  0.09555763648010512
# Row index:  543
# Similarity:  0.1278483901080495
# Row index:  544
# Similarity:  0.06368938709211303
# Row index:  545
# Similarity:  0.12917122661105557
# Row index:  546
# Similarity:  0.19969514289768306
# Row index:  547
# Similarity:  0.03461160877674433
# Row index:  548
# Similarity:  0.05660659491662032
# Row index:  549
# Similarity:  0.1874403722151369
# Row index:  550
# Similarity:  0.06668178896847549
# Row index:  551
# Similarity:  0.05857074126574227
# Row index:  552
# Similarity:  0.08777837604484257
# Row index:  553
# Similarity:  0.0645049428806296
# Row index:  554
# Similarity:  0.0929437349901551
# Row index:  555
# Similarity:  0.11864474946906238
# Row index:  556
# Similarity:  0.10583343916682542
# Row index:  557
# Similarity:  0.13290175844905514
# Row index:  558
# Similarity:  0.14016054795770005
# Row index:  559
# Similarity:  0.12564267775810417
# Row index:  560
# Similarity:  0.02516303948955475
# Row index:  561
# Similarity:  0.10469071079869614
# Row index:  562
# Similarity:  0.11473051335061164
# Row index:  563
# Similarity:  0.0473248524280301
# Row index:  564
# Similarity:  0.15397829514571865
# Row index:  565
# Similarity:  0.04438298374637689
# Row index:  566
# Similarity:  0.08170594879790283
# Row index:  567
# Similarity:  0.07847060257179306
# Row index:  568
# Similarity:  0.049999999999999996
# Row index:  569
# Similarity:  0.09023810998442093
# Row index:  570
# Similarity:  0.06676748934520266
# Row index:  571
# Similarity:  0.0637947289504428
# Row index:  572
# Similarity:  0.08206099398622181
# Row index:  573
# Similarity:  0.11107503021679686
# Row index:  574
# Similarity:  0.08238525545716346
# Row index:  575
# Similarity:  0.06779769220583531
# Row index:  576
# Similarity:  0.10036563193274912
# Row index:  577
# Similarity:  0.06158031204419699
# Row index:  578
# Similarity:  0.09214315876252548
# Row index:  579
# Similarity:  0.07224030685898174
# Row index:  580
# Similarity:  0.08308751175549896
# Row index:  581
# Similarity:  0.05980817386883421
# Row index:  582
# Similarity:  0.05745376632555734
# Row index:  583
# Similarity:  0.2236530118246173
# Row index:  584
# Similarity:  0.09917358170946293
# Row index:  585
# Similarity:  0.16184605289661108
# Row index:  586
# Similarity:  0.07434225106633288
# Row index:  587
# Similarity:  0.12982269672237465
# Row index:  588
# Similarity:  0.08930543165283615
# Row index:  589
# Similarity:  0.13831507318533603
# Row index:  590
# Similarity:  0.15453621147972407
# Row index:  591
# Similarity:  0.17701862643406807
# Row index:  592
# Similarity:  0.13616223548987227
# Row index:  593
# Similarity:  0.04587349021359836
# Row index:  594
# Similarity:  0.04667600280093367
# Row index:  595
# Similarity:  0.047120095940801465
# Row index:  596
# Similarity:  0.1497506232689374
# Row index:  597
# Similarity:  0.12792042981336624
# Row index:  598
# Similarity:  0.13835352988949956
# Row index:  599
# Similarity:  0.08149699421707282
# Row index:  600
# Similarity:  0.07647191129018725
# Row index:  601
# Similarity:  0.16048762736987793
# Row index:  602
# Similarity:  0.13148867643508827
# Row index:  603
# Similarity:  0.03228432090143303
# Row index:  604
# Similarity:  0.1305000397701628
# Row index:  605
# Similarity:  0.06997201678880784
# Row index:  606
# Similarity:  0.0873870841821794
# Row index:  607
# Similarity:  0.0983494740586804
# Row index:  608
# Similarity:  0.09375508667697943
# Row index:  609
# Similarity:  0.10795837927188262
# Row index:  610
# Similarity:  0.10758870794731086
# Row index:  611
# Similarity:  0.030779350562554625
# Row index:  612
# Similarity:  0.07259540086406277
# Row index:  613
# Similarity:  0.08970662047374946
# Row index:  614
# Similarity:  0.12129967060685957
# Row index:  615
# Similarity:  0.10702000341666826
# Row index:  616
# Similarity:  0.2065285172464543
# Row index:  617
# Similarity:  0.1115845940529651
# Row index:  618
# Similarity:  0.06509445549041193
# Row index:  619
# Similarity:  0.07733088933397006
# Row index:  620
# Similarity:  0.07292062297098399
# Row index:  621
# Similarity:  0.042140817041573055
# Row index:  622
# Similarity:  0.12440431775606646
# Row index:  623
# Similarity:  0.10432416355380819
# Row index:  624
# Similarity:  0.12202837367527714
# Row index:  625
# Similarity:  0.10645260986261718
# Row index:  626
# Similarity:  0.09192236218892039
# Row index:  627
# Similarity:  0.057091904964073396
# Row index:  628
# Similarity:  0.0762739254271382
# Row index:  629
# Similarity:  0.06194932847291901
# Row index:  630
# Similarity:  0.05360562674188974
# Row index:  631
# Similarity:  0.1207771456767694
# Row index:  632
# Similarity:  0.07728116040079153
# Row index:  633
# Similarity:  0.0886076503963696
# Row index:  634
# Similarity:  0.07262411172176585
# Row index:  635
# Similarity:  0.09464146221095039
# Row index:  636
# Similarity:  0.13326198405817027
# Row index:  637
# Similarity:  0.0658617301295846
# Row index:  638
# Similarity:  0.13509093288467736
# Row index:  639
# Similarity:  0.0655297582910654
# Row index:  640
# Similarity:  0.05967623950328607
# Row index:  641
# Similarity:  0.153931568576809
# Row index:  642
# Similarity:  0.08924260293142748
# Row index:  643
# Similarity:  0.11706691766863615
# Row index:  644
# Similarity:  0.255917979001179
# Row index:  645
# Similarity:  0.0951901405043207
# Row index:  646
# Similarity:  0.09803479521381729
# Row index:  647
# Similarity:  0.05933055656682091
# Row index:  648
# Similarity:  0.09421114395319914
# Row index:  649
# Similarity:  0.10127393670836665
# Row index:  650
# Similarity:  0.1330961988227338
# Row index:  651
# Similarity:  0.1510015420104719
# Row index:  652
# Similarity:  0.08441703728411586
# Row index:  653
# Similarity:  0.13985041842941953
# Row index:  654
# Similarity:  0.10572282513198254
# Row index:  655
# Similarity:  0.14217778114791785
# Row index:  656
# Similarity:  0.055607067440108786
# Row index:  657
# Similarity:  0.07490594889215628
# Row index:  658
# Similarity:  0.074157636248185
# Row index:  659
# Similarity:  0.08438530156892918
# Row index:  660
# Similarity:  0.16585563184555036
# Row index:  661
# Similarity:  0.12344951946769633
# Row index:  662
# Similarity:  0.047216058305839456
# Row index:  663
# Similarity:  0.0694466316365977
# Row index:  664
# Similarity:  0.06827400253107617
# Row index:  665
# Similarity:  0.05755412232575112
# Row index:  666
# Similarity:  0.2581257075765531
# Row index:  667
# Similarity:  0.2280142389566137
# Row index:  668
# Similarity:  0.10763594508589294
# Row index:  669
# Similarity:  0.06015207623173694
# Row index:  670
# Similarity:  0.17283953107215483
# Row index:  671
# Similarity:  0.11622905250359436
# Row index:  672
# Similarity:  0.13135988668740214
# Row index:  673
# Similarity:  0.08108437164260031
# Row index:  674
# Similarity:  0.1212678125181665
# Row index:  675
# Similarity:  0.15905831204977736
# Row index:  676
# Similarity:  0.10092629340365775
# Row index:  677
# Similarity:  0.13074409009212268
# Row index:  678
# Similarity:  0.05664916757413629
# Row index:  679
# Similarity:  0.06455345827742986
# Row index:  680
# Similarity:  0.11005006888639714
# Row index:  681
# Similarity:  0.11551284429847784
# Row index:  682
# Similarity:  0.09409522026717085
# Row index:  683
# Similarity:  0.10662279799663663
# Row index:  684
# Similarity:  0.0840418565444115
# Row index:  685
# Similarity:  0.05270462766947298
# Row index:  686
# Similarity:  0.11215007691282602
# Row index:  687
# Similarity:  0.06258487442501234
# Row index:  688
# Similarity:  0.04357102009502991
# Row index:  689
# Similarity:  0.04157653749630318
# Row index:  690
# Similarity:  0.11087864652947611
# Row index:  691
# Similarity:  0.07076475519120257
# Row index:  692
# Similarity:  0.1046131561931883
# Row index:  693
# Similarity:  0.10845419199971829
# Row index:  694
# Similarity:  0.11295983527623114
# Row index:  695
# Similarity:  0.11678832116788321
# Row index:  696
# Similarity:  0.06347679914192295
# Row index:  697
# Similarity:  0.059247882157501534
# Row index:  698
# Similarity:  0.13619723901901856
# Row index:  699
# Similarity:  0.1672219365527199
# Row index:  700
# Similarity:  0.09974273175796118
# Row index:  701
# Similarity:  0.0625498842764385
# Row index:  702
# Similarity:  0.09526510164590818
# Row index:  703
# Similarity:  0.14659886790209345
# Row index:  704
# Similarity:  0.09151426977546175
# Row index:  705
# Similarity:  0.09938079899999065
# Row index:  706
# Similarity:  0.18630173038815045
# Row index:  707
# Similarity:  0.10946586116813159
# Row index:  708
# Similarity:  0.05492942180025514
# Row index:  709
# Similarity:  0.06969021858406184
# Row index:  710
# Similarity:  0.08108293197264038
# Row index:  711
# Similarity:  0.019687480773953943
# Row index:  712
# Similarity:  0.08408749651825216
# Row index:  713
# Similarity:  0.051209155649918923
# Row index:  714
# Similarity:  0.07582342329348174
# Row index:  715
# Similarity:  0.14865122502276013
# Row index:  716
# Similarity:  0.17417496250243322
# Row index:  717
# Similarity:  0.12903583341622094
# Row index:  718
# Similarity:  0.09486832980505137
# Row index:  719
# Similarity:  0.09987912576246254
# Row index:  720
# Similarity:  0.17370802593934484
# Row index:  721
# Similarity:  0.09338479919516196
# Row index:  722
# Similarity:  0.1544689411561872
# Row index:  723
# Similarity:  0.0639137490706142
# Row index:  724
# Similarity:  0.10891181949155619
# Row index:  725
# Similarity:  0.15684365432908878
# Row index:  726
# Similarity:  0.060006858318591295
# Row index:  727
# Similarity:  0.09216889583377277
# Row index:  728
# Similarity:  0.056411089755291785
# Row index:  729
# Similarity:  0.11820135721116254
# Row index:  730
# Similarity:  0.1177075137740961
# Row index:  731
# Similarity:  0.07562683160950796
# Row index:  732
# Similarity:  0.09949366763261819
# Row index:  733
# Similarity:  0.058834840541455206
# Row index:  734
# Similarity:  0.10625640436730681
# Row index:  735
# Similarity:  0.10264286388534141
# Row index:  736
# Similarity:  0.06517340573833763
# Row index:  737
# Similarity:  0.07822299479882557
# Row index:  738
# Similarity:  0.09126427969889893
# Row index:  739
# Similarity:  0.1171839238850142
# Row index:  740
# Similarity:  0.08968717116768107
# Row index:  741
# Similarity:  0.09584676765970461
# Row index:  742
# Similarity:  0.11416500379495255
# Row index:  743
# Similarity:  0.029716081940637275
# Row index:  744
# Similarity:  0.11759010854794966
# Row index:  745
# Similarity:  0.154713186938819
# Row index:  746
# Similarity:  0.02258769757263128
# Row index:  747
# Similarity:  0.1347712291935118
# Row index:  748
# Similarity:  0.07587087446739768
# Row index:  749
# Similarity:  0.06235106023789484
# Row index:  750
# Similarity:  0.09423161149839034
# Row index:  751
# Similarity:  0.053511565208216386
# Row index:  752
# Similarity:  0.16783299766767368
# Row index:  753
# Similarity:  0.05811836557697651
# Row index:  754
# Similarity:  0.10267140383606656
# Row index:  755
# Similarity:  0.1365577483997838
# Row index:  756
# Similarity:  0.14864362196288647
# Row index:  757
# Similarity:  0.23657880585413277
# Row index:  758
# Similarity:  0.10925355610938448
# Row index:  759
# Similarity:  0.09942645983355074
# Row index:  760
# Similarity:  0.12346619958119869
# Row index:  761
# Similarity:  0.11710800875382398
# Row index:  762
# Similarity:  0.03219113899898252
# Row index:  763
# Similarity:  0.11684712565567801
# Row index:  764
# Similarity:  0.12346098992700193
# Row index:  765
# Similarity:  0.10657169831489237
# Row index:  766
# Similarity:  0.07937650825657613
# Row index:  767
# Similarity:  0.15652765711214212
# Row index:  768
# Similarity:  0.10829823076731362
# Row index:  769
# Similarity:  0.10038502480061359
# Row index:  770
# Similarity:  0.10176144730133678
# Row index:  771
# Similarity:  0.08080749189443176
# Row index:  772
# Similarity:  0.10003325758087624
# Row index:  773
# Similarity:  0.06043978852154995
# Row index:  774
# Similarity:  0.12735006525127723
# Row index:  775
# Similarity:  0.09075168012986737
# Row index:  776
# Similarity:  0.05975550263548289
# Row index:  777
# Similarity:  0.10857799819528041
# Row index:  778
# Similarity:  0.11646294513905799
# Row index:  779
# Similarity:  0.043193421279068
# Row index:  780
# Similarity:  0.06985666147512158
# Row index:  781
# Similarity:  0.09980305249223753
# Row index:  782
# Similarity:  0.029424494316824985
# Row index:  783
# Similarity:  0.12644740374533614
# Row index:  784
# Similarity:  0.16499158227686112
# Row index:  785
# Similarity:  0.10004850465546955
# Row index:  786
# Similarity:  0.06356160452261518
# Row index:  787
# Similarity:  0.04909361489311344
# Row index:  788
# Similarity:  0.059684742208964796
# Row index:  789
# Similarity:  0.12174117609239957
# Row index:  790
# Similarity:  0.06001056278865802
# Row index:  791
# Similarity:  0.0831626103489811
# Row index:  792
# Similarity:  0.053763504290381584
# Row index:  793
# Similarity:  0.0960712667680402
# Row index:  794
# Similarity:  0.07217574537964583
# Row index:  795
# Similarity:  0.0917406767423889
# Row index:  796
# Similarity:  0.09606047309259091
# Row index:  797
# Similarity:  0.06780635036208105
# Row index:  798
# Similarity:  0.058313089246888765
# Row index:  799
# Similarity:  0.034725571686583676
# Row index:  800
# Similarity:  0.09379987913699099
# Row index:  801
# Similarity:  0.07923044809025473
# Row index:  802
# Similarity:  0.15940146533090443
# Row index:  803
# Similarity:  0.11120854262182925
# Row index:  804
# Similarity:  0.07462765263724078
# Row index:  805
# Similarity:  0.17598707127425525
# Row index:  806
# Similarity:  0.08065179847903307
# Row index:  807
# Similarity:  0.08352690695845569
# Row index:  808
# Similarity:  0.11832859756131864
# Row index:  809
# Similarity:  0.06175402271944636
# Row index:  810
# Similarity:  0.10777205024873014
# Row index:  811
# Similarity:  0.12738201456227885
# Row index:  812
# Similarity:  0.05413319619607667
# Row index:  813
# Similarity:  0.19599157740244455
# Row index:  814
# Similarity:  0.14118236525369518
# Row index:  815
# Similarity:  0.13984069419889722
# Row index:  816
# Similarity:  0.10775909176456294
# Row index:  817
# Similarity:  0.2291393639100087
# Row index:  818
# Similarity:  0.09688834697039746
# Row index:  819
# Similarity:  0.07111823583447563
# Row index:  820
# Similarity:  0.0648557064392552
# Row index:  821
# Similarity:  0.08498617670612563
# Row index:  822
# Similarity:  0.058537281827841306
# Row index:  823
# Similarity:  0.05892556509887897
# Row index:  824
# Similarity:  0.12793235053236218
# Row index:  825
# Similarity:  0.07707213473886947
# Row index:  826
# Similarity:  0.07189966356788134
# Row index:  827
# Similarity:  0.1479523069163941
# Row index:  828
# Similarity:  0.06572670690061994
# Row index:  829
# Similarity:  0.10260908682177604
# Row index:  830
# Similarity:  0.2692343094816518
# Row index:  831
# Similarity:  0.09362506583014757
# Row index:  832
# Similarity:  0.1267165809286535
# Row index:  833
# Similarity:  0.0989726830171203
# Row index:  834
# Similarity:  0.06829479558851911
# Row index:  835
# Similarity:  0.1125087900926024
# Row index:  836
# Similarity:  0.11000840496322105
# Row index:  837
# Similarity:  0.13694358361599301
# Row index:  838
# Similarity:  0.10333338939530026
# Row index:  839
# Similarity:  0.12991615318852104
# Row index:  840
# Similarity:  0.07305950062660078
# Row index:  841
# Similarity:  0.10309670614335874
# Row index:  842
# Similarity:  0.0829184989234173
# Row index:  843
# Similarity:  0.10802183949770962
# Row index:  844
# Similarity:  0.17622358839597738
# Row index:  845
# Similarity:  0.10524696231684351
# Row index:  846
# Similarity:  0.07303271742731404
# Row index:  847
# Similarity:  0.14479918011718576
# Row index:  848
# Similarity:  0.098894350660655
# Row index:  849
# Similarity:  0.19095101399306844
# Row index:  850
# Similarity:  0.09142519016794597
# Row index:  851
# Similarity:  0.06734350297014739
# Row index:  852
# Similarity:  0.12126781251816651
# Row index:  853
# Similarity:  0.15197586589727557
# Row index:  854
# Similarity:  0.03603749850782236
# Row index:  855
# Similarity:  0.07259540086406277
# Row index:  856
# Similarity:  0.15891043154093204
# Row index:  857
# Similarity:  0.0708683386892301
# Row index:  858
# Similarity:  0.12630179559013452
# Row index:  859
# Similarity:  0.09275795723482445
# Row index:  860
# Similarity:  0.08281849174905268
# Row index:  861
# Similarity:  0.07891158215445584
# Row index:  862
# Similarity:  0.13233140759453638
# Row index:  863
# Similarity:  0.10847769259554095
# Row index:  864
# Similarity:  0.04919520370144727
# Row index:  865
# Similarity:  0.11286354261647435
# Row index:  866
# Similarity:  0.10829972051127192
# Row index:  867
# Similarity:  0.043344184115389046
# Row index:  868
# Similarity:  0.14638501094227999
# Row index:  869
# Similarity:  0.08117067346319898
# Row index:  870
# Similarity:  0.0237607458139946
# Row index:  871
# Similarity:  0.057342291071915755
# Row index:  872
# Similarity:  0.042683279491835424
# Row index:  873
# Similarity:  0.09266418641413898
# Row index:  874
# Similarity:  0.12098807094023803
# Row index:  875
# Similarity:  0.05810379255831446
# Row index:  876
# Similarity:  0.07372097807744857
# Row index:  877
# Similarity:  0.10345428255088242
# Row index:  878
# Similarity:  0.12551556615447224
# Row index:  879
# Similarity:  0.11111252822718078
# Row index:  880
# Similarity:  0.053184885466786416
# Row index:  881
# Similarity:  0.058411279723107765
# Row index:  882
# Similarity:  0.09737260471306501
# Row index:  883
# Similarity:  0.04266186757129765
# Row index:  884
# Similarity:  0.051309941332246624
# Row index:  885
# Similarity:  0.08751434000444848
# Row index:  886
# Similarity:  0.09523898764485159
# Row index:  887
# Similarity:  0.10474793930096664
# Row index:  888
# Similarity:  0.0539291857441195
# Row index:  889
# Similarity:  0.08134892168199606
# Row index:  890
# Similarity:  0.11294247573370596
# Row index:  891
# Similarity:  0.07863494569945381
# Row index:  892
# Similarity:  0.10106261892629637
# Row index:  893
# Similarity:  0.13366037652862364
# Row index:  894
# Similarity:  0.0895909654814056
# Row index:  895
# Similarity:  0.13069452638811943
# Row index:  896
# Similarity:  0.14922543671868793
# Row index:  897
# Similarity:  0.039999999999999994
# Row index:  898
# Similarity:  0.05657397385713199
# Row index:  899
# Similarity:  0.1689343445998715
# Row index:  900
# Similarity:  0.04545642385797848
# Row index:  901
# Similarity:  0.18133616797797827
# Row index:  902
# Similarity:  0.10641158459568295
# Row index:  903
# Similarity:  0.14027090192169553
# Row index:  904
# Similarity:  0.10601302391103291
# Row index:  905
# Similarity:  0.05673070188667116
# Row index:  906
# Similarity:  0.03715188083835686
# Row index:  907
# Similarity:  0.10462776733243281
# Row index:  908
# Similarity:  0.10041928905068677
# Row index:  909
# Similarity:  0.13563002367252736
# Row index:  910
# Similarity:  0.04026256277858494
# Row index:  911
# Similarity:  0.09622504486493763
# Row index:  912
# Similarity:  0.11169437554445213
# Row index:  913
# Similarity:  0.13402192668680965
# Row index:  914
# Similarity:  0.17560148562387776
# Row index:  915
# Similarity:  0.04619726191168247
# Row index:  916
# Similarity:  0.1304433211405088
# Row index:  917
# Similarity:  0.05212860351426869
# Row index:  918
# Similarity:  0.05607016300203208
# Row index:  919
# Similarity:  0.07927524902574902
# Row index:  920
# Similarity:  0.09263671131731707
# Row index:  921
# Similarity:  0.10642499246880309
# Row index:  922
# Similarity:  0.10253788905369948
# Row index:  923
# Similarity:  0.07054756215026585
# Row index:  924
# Similarity:  0.060241449667687415
# Row index:  925
# Similarity:  0.054104577004969255
# Row index:  926
# Similarity:  0.10497984580422266
# Row index:  927
# Similarity:  0.11660190581423469
# Row index:  928
# Similarity:  0.024619956161197977
# Row index:  929
# Similarity:  0.07006490497453706
# Row index:  930
# Similarity:  0.13451362256152108
# Row index:  931
# Similarity:  0.11656310103003922
# Row index:  932
# Similarity:  0.08867102661511511
# Row index:  933
# Similarity:  0.17069458338865404
# Row index:  934
# Similarity:  0.05689938022512019
# Row index:  935
# Similarity:  0.07710416486201307
# Row index:  936
# Similarity:  0.04259988603693732
# Row index:  937
# Similarity:  0.1359401280133684
# Row index:  938
# Similarity:  0.08082238591204871
# Row index:  939
# Similarity:  0.053203533172421796
# Row index:  940
# Similarity:  0.09842837457201914
# Row index:  941
# Similarity:  0.12388341394500438
# Row index:  942
# Similarity:  0.14355660723818642
# Row index:  943
# Similarity:  0.13014919828340785
# Row index:  944
# Similarity:  0.06666666666666665
# Row index:  945
# Similarity:  0.0636929755298482
# Row index:  946
# Similarity:  0.1116919564249616
# Row index:  947
# Similarity:  0.06704015231539909
# Row index:  948
# Similarity:  0.1317388888104585
# Row index:  949
# Similarity:  0.12361891755295334
# Row index:  950
# Similarity:  0.06250488338477911
# Row index:  951
# Similarity:  0.07703945430349209
# Row index:  952
# Similarity:  0.06366004326312026
# Row index:  953
# Similarity:  0.08695753644243503
# Row index:  954
# Similarity:  0.10939931189758582
# Row index:  955
# Similarity:  0.0975621363797355
# Row index:  956
# Similarity:  0.14484765414696021
# Row index:  957
# Similarity:  0.06026203312353246
# Row index:  958
# Similarity:  0.028958149517537956
# Row index:  959
# Similarity:  0.11867816581938534
# Row index:  960
# Similarity:  0.07895420339517228
# Row index:  961
# Similarity:  0.0721873527429636
# Row index:  962
# Similarity:  0.14908155174502397
# Row index:  963
# Similarity:  0.06932826656369176
# Row index:  964
# Similarity:  0.04525756964727324
# Row index:  965
# Similarity:  0.0237607458139946
# Row index:  966
# Similarity:  0.2496751135729437
# Row index:  967
# Similarity:  0.049088069367381595
# Row index:  968
# Similarity:  0.05216317330599466
# Row index:  969
# Similarity:  0.12255933265480042
# Row index:  970
# Similarity:  0.048935018292891964
# Row index:  971
# Similarity:  0.02572999105304042
# Row index:  972
# Similarity:  0.04283038222833494
# Row index:  973
# Similarity:  0.10585122480499264
# Row index:  974
# Similarity:  0.174570486447536
# Row index:  975
# Similarity:  0.1651445647689541
# Row index:  976
# Similarity:  0.13979665093557234
# Row index:  977
# Similarity:  0.10330825662358101
# Row index:  978
# Similarity:  0.0657793514480272
# Row index:  979
# Similarity:  0.14509525002200235
# Row index:  980
# Similarity:  0.07650782332492291
# Row index:  981
# Similarity:  0.06998304088731733
# Row index:  982
# Similarity:  0.1549279173501925
# Row index:  983
# ...
# Similarity:  0.07174692943795125
# Row index:  2680
# Similarity:  0.11135885079684349
# Row index:  2681
# Similarity:  0.05938556868486719
# Row index:  2682
# Similarity:  0.03910122602594405
# Row index:  2683
# Similarity:  0.07842132304259755
# Row index:  2684
# Similarity:  0.11945220005766044
# Row index:  2685
# Similarity:  0.04670993664969138
# Row index:  2686
# Similarity:  0.10448966485787865
# Row index:  2687
# Similarity:  0.12082882855777055
# Row index:  2688
# Similarity:  0.09479229241267713
# Row index:  2689
# Similarity:  0.08130545444849886
# Row index:  2690
# Similarity:  0.06036726311049255
# Row index:  2691
# Similarity:  0.07147389892425668
# Row index:  2692
# Similarity:  0.08362903435048052
# Row index:  2693
# Similarity:  0.09651100402393104
# Row index:  2694
# Similarity:  0.08113277010250904
# Row index:  2695
# Similarity:  0.05972983573521363
# Row index:  2696
# Similarity:  0.07414734221668819
# Row index:  2697
# Similarity:  0.14030530132648025
# Row index:  2698
# Similarity:  0.10443868185174138
# Row index:  2699
# Similarity:  0.02000100007500625
# Row index:  2700
# Similarity:  0.0939060283031685
# Row index:  2701
# Similarity:  0.07962663020475631
# Row index:  2702
# Similarity:  0.060189519171081306
# Row index:  2703
# Similarity:  0.06676748934520266
# Row index:  2704
# Similarity:  0.07060180864974624
# Row index:  2705
# Similarity:  0.06871005307930775
# Row index:  2706
# Similarity:  0.12190439333572474
# Row index:  2707
# Similarity:  0.10576238616172541
# Row index:  2708
# Similarity:  0.07373700960489207
# Row index:  2709
# Similarity:  0.12480117690611711
# Row index:  2710
# Similarity:  0.13880146207166918
# Row index:  2711
# Similarity:  0.10712099794500794
# Row index:  2712
# Similarity:  0.06472796978171812
# Row index:  2713
# Similarity:  0.12336003250126083
# Row index:  2714
# Similarity:  0.100802456126501
# Row index:  2715
# Similarity:  0.1289409776805375
# Row index:  2716
# Similarity:  0.1148792271411112
# Row index:  2717
# Similarity:  0.031108550841912757
# Row index:  2718
# Similarity:  0.10732870785867239
# Row index:  2719
# Similarity:  0.15288571916666896
# Row index:  2720
# Similarity:  0.16156075826981242
# Row index:  2721
# Similarity:  0.12943655934564638
# Row index:  2722
# Similarity:  0.1378179942706202
# Row index:  2723
# Similarity:  0.0533676050223615
# Row index:  2724
# Similarity:  0.1161011525004825
# Row index:  2725
# Similarity:  0.1252097903573989
# Row index:  2726
# Similarity:  0.11312200306150094
# Row index:  2727
# Similarity:  0.09137725303127417
# Row index:  2728
# Similarity:  0.02957136460079067
# Row index:  2729
# Similarity:  0.09411096075057525
# Row index:  2730
# Similarity:  0.11811389781538352
# Row index:  2731
# Similarity:  0.12953659193925487
# Row index:  2732
# Similarity:  0.06685478776986835
# Row index:  2733
# Similarity:  0.09087485030879801
# Row index:  2734
# Similarity:  0.07235359517703827
# Row index:  2735
# Similarity:  0.05587169827934082
# Row index:  2736
# Similarity:  0.13010895966405667
# Row index:  2737
# Similarity:  0.10999438818457405
# Row index:  2738
# Similarity:  0.12168242151533848
# Row index:  2739
# Similarity:  0.11831213107007525
# Row index:  2740
# Similarity:  0.12532508922500873
# Row index:  2741
# Similarity:  0.10838393891146714
# Row index:  2742
# Similarity:  0.0539291857441195
# Row index:  2743
# Similarity:  0.07776266761630565
# Row index:  2744
# Similarity:  0.059386861516370563
# Row index:  2745
# Similarity:  0.08345796191413744
# Row index:  2746
# Similarity:  0.10279434991718928
# Row index:  2747
# Similarity:  0.08914849883204186
# Row index:  2748
# Similarity:  0.039528470752104736
# Row index:  2749
# Similarity:  0.14907119849998599
# Row index:  2750
# Similarity:  0.06009623101612528
# Row index:  2751
# Similarity:  0.12002400720240085
# Row index:  2752
# Similarity:  0.0818545509070058
# Row index:  2753
# Similarity:  0.10505757987322582
# Row index:  2754
# Similarity:  0.09796244778275266
# Row index:  2755
# Similarity:  0.09432422182837985
# Row index:  2756
# Similarity:  0.12575445656392525
# Row index:  2757
# Similarity:  0.12172168970954687
# Row index:  2758
# Similarity:  0.06873217490352687
# Row index:  2759
# Similarity:  0.11182650591230865
# Row index:  2760
# Similarity:  0.02678998598884099
# Row index:  2761
# Similarity:  0.15288200191119283
# Row index:  2762
# Similarity:  0.07737946312060223
# Row index:  2763
# Similarity:  0.10502100630210072
# Row index:  2764
# Similarity:  0.10488730668544685
# Row index:  2765
# Similarity:  0.0797663608445026
# Row index:  2766
# Similarity:  0.10720031746564691
# Row index:  2767
# Similarity:  0.11141412945539661
# Row index:  2768
# Similarity:  0.07099169533382993
# Row index:  2769
# Similarity:  0.1175623414086232
# Row index:  2770
# Similarity:  0.17404116168780087
# Row index:  2771
# Similarity:  0.13972333788326563
# Row index:  2772
# Similarity:  0.06308686733535498
# Row index:  2773
# Similarity:  0.04545584987666715
# Row index:  2774
# Similarity:  0.11311759248105613
# Row index:  2775
# Similarity:  0.13351839009599825
# Row index:  2776
# Similarity:  0.1019294382875251
# Row index:  2777
# Similarity:  0.11902930262023968
# Row index:  2778
# Similarity:  0.11281521496355325
# Row index:  2779
# Similarity:  0.04851505295126123
# Row index:  2780
# Similarity:  0.10190650087739495
# Row index:  2781
# Similarity:  0.08299110053897532
# Row index:  2782
# Similarity:  0.0886123278691662
# Row index:  2783
# Similarity:  0.08657506729914204
# Row index:  2784
# Similarity:  0.10116897146678411
# Row index:  2785
# Similarity:  0.09244023874976197
# Row index:  2786
# Similarity:  0.07254762501100116
# Row index:  2787
# Similarity:  0.0777713771047819
# Row index:  2788
# Similarity:  0.1002560823655206
# Row index:  2789
# Similarity:  0.06185895741317419
# Row index:  2790
# Similarity:  0.06654004420351663
# Row index:  2791
# Similarity:  0.1661625969589056
# Row index:  2792
# Similarity:  0.0832250378576479
# Row index:  2793
# Similarity:  0.135116001384382
# Row index:  2794
# Similarity:  0.08717100546930083
# Row index:  2795
# Similarity:  0.07216878364870322
# Row index:  2796
# Similarity:  0.16923874942651676
# Row index:  2797
# Similarity:  0.14092000720223158
# Row index:  2798
# Similarity:  0.05745376632555734
# Row index:  2799
# Similarity:  0.12183450627436634
# Row index:  2800
# Similarity:  0.039254643313832986
# Row index:  2801
# Similarity:  0.042295493443781355
# Row index:  2802
# Similarity:  0.06899649886853541
# Row index:  2803
# Similarity:  0.08130718923008945
# Row index:  2804
# Similarity:  0.09142475696046329
# Row index:  2805
# Similarity:  0.09621595459569389
# Row index:  2806
# Similarity:  0.07237261868600828
# Row index:  2807
# Similarity:  0.02279211529192759
# Row index:  2808
# Similarity:  0.0938351290644441
# Row index:  2809
# Similarity:  0.16956852499052755
# Row index:  2810
# Similarity:  0.07491950477531918
# Row index:  2811
# Similarity:  0.10956642697819578
# Row index:  2812
# Similarity:  0.050251890762960605
# Row index:  2813
# Similarity:  0.15214515486254615
# Row index:  2814
# Similarity:  0.10226199851298273
# Row index:  2815
# Similarity:  0.098355522277054
# Row index:  2816
# Similarity:  0.08002048786767696
# Row index:  2817
# Similarity:  0.15044961347377478
# Row index:  2818
# Similarity:  0.03921191752852306
# Row index:  2819
# Similarity:  0.12681870679376742
# Row index:  2820
# Similarity:  1.0
# Row index:  2821
# Similarity:  0.1233803164995542
# Row index:  2822
# Similarity:  0.08315243710448904
# Row index:  2823
# Similarity:  0.12007532848817218
# Row index:  2824
# Similarity:  0.0774455871881556
# Row index:  2825
# Similarity:  0.11393098783744388
# Row index:  2826
# Similarity:  0.10481984502994841
# Row index:  2827
# Similarity:  0.10978113200356095
# Row index:  2828
# Similarity:  0.04755439172009177
# Row index:  2829
# Similarity:  0.040343576522993925
# Row index:  2830
# Similarity:  0.14639834959199033
# Row index:  2831
# Similarity:  0.1254363015010636
# Row index:  2832
# Similarity:  0.1562904982411873
# Row index:  2833
# Similarity:  0.07295405746286962
# Row index:  2834
# Similarity:  0.15846642276159686
# Row index:  2835
# Similarity:  0.1019532743068339
# Row index:  2836
# Similarity:  0.11908390432199613
# Row index:  2837
# Similarity:  0.06243905410544627
# Row index:  2838
# Similarity:  0.232942834333321
# Row index:  2839
# Similarity:  0.07571128605199565
# Row index:  2840
# Similarity:  0.06868028197434452
# Row index:  2841
# Similarity:  0.09248709425418192
# Row index:  2842
# Similarity:  0.16865480854231357
# Row index:  2843
# Similarity:  0.06457962733644264
# Row index:  2844
# Similarity:  0.08593456717838992
# Row index:  2845
# Similarity:  0.14509525002200235
# Row index:  2846
# Similarity:  0.11744404390294069
# Row index:  2847
# Similarity:  0.05194805194805195
# Row index:  2848
# Similarity:  0.17282334873479874
# Row index:  2849
# Similarity:  0.06858449352888188
# Row index:  2850
# Similarity:  0.05791629903507591
# Row index:  2851
# Similarity:  0.06536366562603768
# Row index:  2852
# Similarity:  0.13707583482392446
# Row index:  2853
# Similarity:  0.11198865732661313
# Row index:  2854
# Similarity:  0.06487045463518618
# Row index:  2855
# Similarity:  0.11087107424795299
# Row index:  2856
# Similarity:  0.06339841120396944
# Row index:  2857
# Similarity:  0.09613199155372196
# Row index:  2858
# Similarity:  0.04139604934956612
# Row index:  2859
# Similarity:  0.11721705250676619
# Row index:  2860
# Similarity:  0.03892848632225431
# Row index:  2861
# Similarity:  0.11448395504925057
# Row index:  2862
# Similarity:  0.041959067914834454
# Row index:  2863
# Similarity:  0.07548513560963972
# Row index:  2864
# Similarity:  0.08084520834544434
# Row index:  2865
# Similarity:  0.16222142113076254
# Row index:  2866
# Similarity:  0.1681399675247142
# Row index:  2867
# Similarity:  0.06202213841183978
# Row index:  2868
# Similarity:  0.0922592552658273
# Row index:  2869
# Similarity:  0.0844731994270118
# Row index:  2870
# Similarity:  0.05568460463897045
# Row index:  2871
# Similarity:  0.046584749531245626
# Row index:  2872
# Similarity:  0.08481041912882635
# Row index:  2873
# Similarity:  0.07590680990538863
# Row index:  2874
# Similarity:  0.05273686560750369
# Row index:  2875
# Similarity:  0.050192512400306796
# Row index:  2876
# Similarity:  0.08257978997938137
# Row index:  2877
# Similarity:  0.10509273941090883
# Row index:  2878
# Similarity:  0.05161500868845837
# Row index:  2879
# Similarity:  0.13046561461068845
# Row index:  2880
# Similarity:  0.17191624218032073
# Row index:  2881
# Similarity:  0.09791840981793673
# Row index:  2882
# Similarity:  0.10094660663590603
# Row index:  2883
# Similarity:  0.08045179867091298
# Row index:  2884
# Similarity:  0.07172268245577411
# Row index:  2885
# Similarity:  0.10350983390135313
# Row index:  2886
# Similarity:  0.05001852881293914
# Row index:  2887
# Similarity:  0.08291561975888499
# Row index:  2888
# Similarity:  0.11389336290235505
# Row index:  2889
# Similarity:  0.09944466052196625
# Row index:  2890
# Similarity:  0.09731142770868029
# Row index:  2891
# Similarity:  0.08806599154457967
# Row index:  2892
# Similarity:  0.11927107455535572
# Row index:  2893
# Similarity:  0.07166776363062763
# Row index:  2894
# Similarity:  0.12651201921276495
# Row index:  2895
# Similarity:  0.06297908559918702
# Row index:  2896
# Similarity:  0.08740073734751264
# Row index:  2897
# Similarity:  0.10527400374124327
# Row index:  2898
# Similarity:  0.06666666666666665
# Row index:  2899
# Similarity:  0.12413663210862388
# Row index:  2900
# Similarity:  0.09076352477286181
# Row index:  2901
# Similarity:  0.16182267881254697
# Row index:  2902
# Similarity:  0.14174832146883995
# Row index:  2903
# Similarity:  0.16997516472311203
# Row index:  2904
# Similarity:  0.11684747893443544
# Row index:  2905
# Similarity:  0.04195906791483445
# Row index:  2906
# Similarity:  0.059432163881274556
# Row index:  2907
# Similarity:  0.0702542535690497
# Row index:  2908
# Similarity:  0.10680917396691056
# Row index:  2909
# Similarity:  0.08248900219951125
# Row index:  2910
# Similarity:  0.0590168890850654
# Row index:  2911
# Similarity:  0.09303231294294809
# Row index:  2912
# Similarity:  0.0675737378399486
# Row index:  2913
# Similarity:  0.10980732398991648
# Row index:  2914
# Similarity:  0.05479422312768516
# Row index:  2915
# Similarity:  0.0719378725056482
# Row index:  2916
# Similarity:  0.09432432442624764
# Row index:  2917
# Similarity:  0.06781501183626366
# Row index:  2918
# Similarity:  0.08512565307587486
# Row index:  2919
# Similarity:  0.12761638994974908
# Row index:  2920
# Similarity:  0.07857499910452126
# Row index:  2921
# Similarity:  0.055531565616502375
# Row index:  2922
# Similarity:  0.1450721143684993
# Row index:  2923
# Similarity:  0.10475432492978197
# Row index:  2924
# Similarity:  0.06805713753479713
# Row index:  2925
# Similarity:  0.07782066599596829
# Row index:  2926
# Similarity:  0.16517992562686298
# Row index:  2927
# Similarity:  0.01661482620930756
# Row index:  2928
# Similarity:  0.10223313016447166
# Row index:  2929
# Similarity:  0.14765253271590997
# Row index:  2930
# Similarity:  0.08177139209938224
# Row index:  2931
# Similarity:  0.11578709321745484
# Row index:  2932
# Similarity:  0.07824607964359516
# Row index:  2933
# Similarity:  0.09163112959562265
# Row index:  2934
# Similarity:  0.06785511437439767
# Row index:  2935
# Similarity:  0.043700842860821806
# Row index:  2936
# Similarity:  0.03868392354571063
# Row index:  2937
# Similarity:  0.057507840470538904
# Row index:  2938
# Similarity:  0.06457168933292959
# Row index:  2939
# Similarity:  0.11864596136021177
# Row index:  2940
# Similarity:  0.12467574523850741
# Row index:  2941
# Similarity:  0.06202325772224677
# Row index:  2942
# Similarity:  0.0999791731748236
# Row index:  2943
# Similarity:  0.10886382502152389
# Row index:  2944
# Similarity:  0.1065132198190853
# Row index:  2945
# Similarity:  0.07624928516630233
# Row index:  2946
# Similarity:  0.27486462449313626
# Row index:  2947
# Similarity:  0.05932237473453119
# Row index:  2948
# Similarity:  0.03827327723098716
# Row index:  2949
# Similarity:  0.08485552916276634
# Row index:  2950
# Similarity:  0.10948661653153992
# Row index:  2951
# Similarity:  0.11705785184863782
# Row index:  2952
# Similarity:  0.05892556509887896
# Row index:  2953
# Similarity:  0.09966374072778822
# Row index:  2954
# Similarity:  0.12294604428906898
# Row index:  2955
# Similarity:  0.08749999999999998
# Row index:  2956
# Similarity:  0.12874973247018068
# Row index:  2957
# Similarity:  0.10448370375173427
# Row index:  2958
# Similarity:  0.05985651633507166
# Row index:  2959
# Similarity:  0.0766603206325562
# Row index:  2960
# Similarity:  0.12892156936067814
# Row index:  2961
# Similarity:  0.10729877376023533
# Row index:  2962
# Similarity:  0.10030496079406735
# Row index:  2963
# Similarity:  0.08166982597207062
# Row index:  2964
# Similarity:  0.11930191762861385
# Row index:  2965
# Similarity:  0.11549739373503798
# Row index:  2966
# Similarity:  0.06568640423410897
# Row index:  2967
# Similarity:  0.12158485309192874
# Row index:  2968
# Similarity:  0.06404031539506062
# Row index:  2969
# Similarity:  0.1096797019946582
# Row index:  2970
# Similarity:  0.12930856131611454
# Row index:  2971
# Similarity:  0.10944168462342656
# Row index:  2972
# Similarity:  0.12448264252920549
# Row index:  2973
# Similarity:  0.09372315102530711
# Row index:  2974
# Similarity:  0.15179138720759572
# Row index:  2975
# Similarity:  0.08989331499509894
# Row index:  2976
# Similarity:  0.05695387789781859
# Row index:  2977
# Similarity:  0.12669143726421445
# Row index:  2978
# Similarity:  0.08898251830022487
# Row index:  2979
# Similarity:  0.1384833764711889
# Row index:  2980
# Similarity:  0.09458405897319429
# Row index:  2981
# Similarity:  0.17550018631109668
# Row index:  2982
# Similarity:  0.04588314677411235
# Row index:  2983
# Similarity:  0.17247589883847272
# Row index:  2984
# Similarity:  0.07035975447302918
# Row index:  2985
# Similarity:  0.05660153473298805
# Row index:  2986
# Similarity:  0.13445789780467077
# Row index:  2987
# Similarity:  0.10102135422603399
# Row index:  2988
# Similarity:  0.24044074834338583
# Row index:  2989
# Similarity:  0.05874228140418678
# Row index:  2990
# Similarity:  0.0842151921066519
# Row index:  2991
# Similarity:  0.08703882797784894
# Row index:  2992
# Similarity:  0.11178686357964283
# Row index:  2993
# Similarity:  0.08028970836291949
# Row index:  2994
# Similarity:  0.06438895077385465
# Row index:  2995
# Similarity:  0.04511099683006389
# Row index:  2996
# Similarity:  0.09010819478961825
# Row index:  2997
# Similarity:  0.02519763153394848
# Row index:  2998
# Similarity:  0.11525415451442608
# Row index:  2999
# Similarity:  0.10305134760793029
